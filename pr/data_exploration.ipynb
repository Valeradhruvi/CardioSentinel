# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <center><h1>Exploration using Pandas</h1></center>

# %% [markdown]
# <h3>Reading cardio_train.csv Dataset</h3>

# %%
data = pd.read_csv("C:\\AI-ML\\MLProject\\Data\\cardio_train.csv" , sep=';')
data
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %% [markdown]
# <h3>First 10 records of Dataset</h3>

# %%
data.head(10)
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
# 5   8  21914       1     151    67.0    120     80            2     2      0
# 6   9  22113       1     157    93.0    130     80            3     1      0
# 7  12  22584       2     178    95.0    130     90            3     3      0
# 8  13  17668       1     158    71.0    110     70            1     1      0
# 9  14  19834       1     164    68.0    110     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# ...

# %% [markdown]
# <h3>Count of null values in </h3>

# %%
data.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %% [markdown]
# <h3>Percentage of missing values</h3>

# %%
(data.isnull().mean()*100).sort_values(ascending=False)
# Out:
# id             0.0
# age            0.0
# gender         0.0
# height         0.0
# weight         0.0
# ap_hi          0.0
# ap_lo          0.0
# cholesterol    0.0
# gluc           0.0
# smoke          0.0
# alco           0.0
# active         0.0
# cardio         0.0
# dtype: float64

# %% [markdown]
# <h3>Dimention of dataset</h3>

# %%
data.shape
# Out:
# (70000, 13)

# %% [markdown]
# <h3>Unique Values</h3>

# %% [markdown]
# <h3>Average height</h3>

# %%
print(data['height'].mean())
# Out:
# 164.35922857142856

# %% [markdown]
# <h3>Average weight</h3>

# %%
print(data['weight'].mean())
# Out:
# 74.20569

# %% [markdown]
# <h3>Information of dataset</h3>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %% [markdown]
# <h3>Summary of dataset</h3>

# %%
data.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %% [markdown]
# <h3>Count of Duplicated tuple if any</h3>

# %%
print(data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# <h3>Array of Coulmns</h3>

# %%
print(data.columns)
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %% [markdown]
# <h3>Count of person which are active and have habbit of smoking</h3>

# %%
data["active"].value_counts()
data["smoke"].value_counts()
# Out:
# smoke
# 0    63831
# 1     6169
# Name: count, dtype: int64

# %% [markdown]
# <h3>Cardio disease rate by Gender , Cholestrol , Glucose , Activeness , Alcohol , Smoke</h3>

# %%
data.groupby('gender')['cardio'].mean()
# Out:
# gender
# 1    0.496727
# 2    0.505231
# Name: cardio, dtype: float64

# %%
data.groupby('cholesterol')['cardio'].mean()
# Out:
# cholesterol
# 1    0.440107
# 2    0.602157
# 3    0.765435
# Name: cardio, dtype: float64

# %%
data.groupby('gluc')['cardio'].mean()
# Out:
# gluc
# 1    0.480590
# 2    0.593064
# 3    0.622022
# Name: cardio, dtype: float64

# %%
data.groupby('active')['cardio'].mean()
# Out:
# active
# 0    0.535774
# 1    0.490891
# Name: cardio, dtype: float64

# %%
data.groupby('alco')['cardio'].mean()
# Out:
# alco
# 0    0.500574
# 1    0.484325
# Name: cardio, dtype: float64

# %%
data.groupby('smoke')['cardio'].mean()
# Out:
# smoke
# 0    0.502107
# 1    0.474793
# Name: cardio, dtype: float64

# %% [markdown]
# <h3>Age Grouping</h3>

# %%
data['age_years'] = data['age'] // 365

data['age_group'] = pd.cut(data['age_years'], 
                         bins=[0, 29, 39, 49, 59, 69, 120],
                         labels=['20s','30s','40s','50s','60s','70+'])

data
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
# ...

# %% [markdown]
# <h3>Age Group wise Disease rate</h3>

# %%
data.groupby('age_group')['cardio'].mean()
# Out:
# C:\Users\er_dh\AppData\Local\Temp\ipykernel_13508\454213479.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby('age_group')['cardio'].mean()
# age_group
# 20s    0.000000
# 30s    0.242560
# 40s    0.379516
# 50s    0.516446
# 60s    0.670038
# 70+         NaN
# Name: cardio, dtype: float64

# %% [markdown]
# <h3>BMI Calculation</h3>

# %%
BmiData = data.copy()

data['BMI'] = data['weight'] / ((data['height'] / 100) ** 2)

data['BMI_group'] = pd.cut(
    BmiData['BMI'],
    bins=[0, 18.5, 25, 30, 100],
    labels=['Underweight', 'Normal', 'Overweight', 'Obese']
)

data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio  age_years age_group        BMI   BMI_group
# 0     0       1       0         50       50s  21.967120      Normal
# 1     0       1       1         55       50s  34.927679       Obese
# 2     0       0       1         51       50s  23.507805      Normal
# 3     0       1       1         48       40s  28.710479  Overweight
# 4     0       0       0         47       40s  23.011177      Normal

# %% [markdown]
# <h3>Correlation of dataset</h3>

# %%
data2 = data.drop(['age_group'], axis=1)
data_numeric = data2.select_dtypes(include=['number'])
correlation = data_numeric.corr()
correlation
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.003457  0.003502 -0.003038 -0.001830  0.003356
# age          0.003457  1.000000 -0.022811 -0.081515  0.053684  0.020764
# gender       0.003502 -0.022811  1.000000  0.499033  0.155406  0.006005
# height      -0.003038 -0.081515  0.499033  1.000000  0.290968  0.005488
# weight      -0.001830  0.053684  0.155406  0.290968  1.000000  0.030702
# ap_hi        0.003356  0.020764  0.006005  0.005488  0.030702  1.000000
# ap_lo       -0.002529  0.017647  0.015254  0.006150  0.043710  0.016086
# cholesterol  0.006106  0.154424 -0.035821 -0.050226  0.141768  0.023778
# gluc         0.002467  0.098703 -0.020491 -0.018595  0.106857  0.011841
# smoke       -0.003699 -0.047633  0.338135  0.187989  0.067780 -0.000922
# alco         0.001210 -0.029723  0.170966  0.094419  0.067113  0.001408
# active       0.003755 -0.009927  0.005866 -0.006570 -0.016867 -0.000033
# ...

# %% [markdown]
# <center><h1>Exploration using matplotlib.pyplot</h1></center>

# %% [markdown]
# <h3>Field wise analysis of dataset plotted in graph</h3>

# %%
data.hist(figsize=(12,12) ,grid=True )
# Out:
# array([[<Axes: title={'center': 'id'}>, <Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'gender'}>,
#         <Axes: title={'center': 'height'}>],
#        [<Axes: title={'center': 'weight'}>,
#         <Axes: title={'center': 'ap_hi'}>,
#         <Axes: title={'center': 'ap_lo'}>,
#         <Axes: title={'center': 'cholesterol'}>],
#        [<Axes: title={'center': 'gluc'}>,
#         <Axes: title={'center': 'smoke'}>,
#         <Axes: title={'center': 'alco'}>,
#         <Axes: title={'center': 'active'}>],
#        [<Axes: title={'center': 'cardio'}>,
#         <Axes: title={'center': 'age_years'}>,
#         <Axes: title={'center': 'BMI'}>, <Axes: >]], dtype=object)

# %% [markdown]
# <h3>Graph showing the ratio of Age vs Cholestrol</h3>

# %%
plt.scatter(data["age"], data["cholesterol"])
plt.xlabel("Age")
plt.ylabel("Cholesterol")
plt.title("Age vs Cholesterol")
plt.show()

# %% [markdown]
# <h3>UnderWeight or Overweight</h3>

# %%
plt.boxplot(data["weight"])
plt.title("Weight Outliers")
plt.show()

# %% [markdown]
# <h3>Cholestrol Levels</h3>

# %%
data["cholesterol"].value_counts().plot(kind="bar")
plt.title("Cholesterol Levels")
plt.show()

# %% [markdown]
# <center><h1>Exploraation using seaborn library</h1></center>

# %% [markdown]
# <h3>Visual representation of missing values</h3>

# %%
sns.heatmap(data.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# <h3>HeatMap of correlation analysis</h3>

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data_numeric.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# <h3>Detection of outliers</h3>

# %%
plt.figure(figsize=(8,5))
plt.scatter(data['ap_hi'], data['ap_lo'])
plt.xlabel('Systolic')
plt.ylabel('Diastolic')
plt.title('Scatter Plot to Detect Outliers')
plt.show()
